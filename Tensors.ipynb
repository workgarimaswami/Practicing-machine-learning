# %%
import numpy as np

# Tensors
# 0D Tensors
a=np.array(4)

# %%
a.ndim
# Out:
# 0

# %%
# 1D tensors
arr=np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.ndim
# Out:
# 1

# %%
# 2D tensors
arr = np.array([[1,2],
               [4,5],
               [6,7]])

# %%
arr
# Out:
# array([[1, 2],
#        [4, 5],
#        [6, 7]])

# %%
arr.ndim
# Out:
# 2
