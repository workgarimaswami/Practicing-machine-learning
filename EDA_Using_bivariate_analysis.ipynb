# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv('/content/tip.csv')

# %%
# df.head()

# %%
titanic = pd.read_csv('/train.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Scatterplot

# %%
sns.scatterplot(
    x='total_bill',
    y='tip',
    hue='sex',
    style='smoker',
    size='size',
    data=tips
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips[tips['sex']=='Female']['smoker'].value_counts()
# Out:
# smoker
# No     54
# Yes    33
# Name: count, dtype: int64

# %%
tips[tips['sex']=='Male']['smoker'].value_counts()
# Out:
# smoker
# No     97
# Yes    60
# Name: count, dtype: int64

# %%
tips.groupby(['sex','smoker'])['total_bill'].mean().round(2)
# Out:
# /tmp/ipykernel_1089/2736291742.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['sex','smoker'])['total_bill'].mean().round(2)
# sex     smoker
# Male    Yes       22.28
#         No        19.79
# Female  Yes       17.98
#         No        18.11
# Name: total_bill, dtype: float64

# %% [markdown]
# BarPlot - Numerical-Categorical

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x='Pclass',y='Age',hue='Sex',data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# Bar plot - Numerical - Categorical

# %%
titanic['Survival_Status'] = titanic['Survived'].map({
    0:'Not survived',
    1:'Survived'
})

# %%
sns.boxplot(x='Sex',y='Age',hue='Survival_Status',data=titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# Distplot(Numerical-Categorical)

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=True)
sns.distplot(titanic[titanic['Survived']==1]['Age'],hist=True)
# Out:
# /tmp/ipykernel_1089/1621799243.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=True)
# /tmp/ipykernel_1089/1621799243.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.kdeplot(
    data=titanic[titanic['Survived']==0],
    x='Age',
    label='Not survived'
)

sns.kdeplot(
    data=titanic[titanic['Survived']==1],
    x='Age',
    label='Survived'
)
plt.legend()

# %% [markdown]
# Heatmap(categorical-categorical)

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Survival_Status
# 0      0         A/5 21171   7.2500   NaN        S    Not survived
# 1      0          PC 17599  71.2833   C85        C        Survived
# 2      0  STON/O2. 3101282   7.9250   NaN        S        Survived

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# pd.crosstab() is used to create a frequency table (counts) between two categorical variables
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Embarked')['Survived'].mean().mul(100).round(2)
# Out:
# Embarked
# C    55.36
# Q    38.96
# S    33.70
# Name: Survived, dtype: float64

# %% [markdown]
# clustermap

# %%
sns.clustermap(pd.crosstab(titanic['Parch'],titanic['Survived']))

# %% [markdown]
# pairplot

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# lineplot

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
new = flights.groupby('year')['passengers'].sum().reset_index()

# %%
sns.lineplot(x=new['year'],y=new['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
# A pivot table is used to summarize data by grouping it into rows and columns and applying an aggregation function (like mean, sum, count).
# Out:
# /tmp/ipykernel_1089/4233458034.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
